# %%
# Import Libraries
# %matplotlib inline
import re
import matplotlib.pyplot as plt
import numpy as np
import Bio.SeqIO as SeqIO
import time
from sklearn.cluster import KMeans, k_means

# %%
# Extract Data
j = 0
dict = []
indonesian_virus = []
for i, record in enumerate(SeqIO.parse("sequence.gb", "genbank")):
    if all (key in record.features[0].qualifiers for key in ('host','country','collection_date')):
        j+=1
        
        host = record.features[0].qualifiers['host'][0]
        host = host.split(';')[0]
        
        location = record.features[0].qualifiers['country'][0]
        location = location.split(':')[0]
        
        year = record.features[0].qualifiers['collection_date'][0]
        year = year.split('-')[-1]
        
        row = {
            'id'          :record.id,
            'name'        :record.name,
            'description' :record.description,
            'host'        :host,
            'location'    :location,
            'year'        :year,
            'seq'         :record.seq,
            'url'         :'http://www.ncbi.nlm.nih.gov/nuccore/'+record.id
        }
        
        if location == 'Indonesia':
            indonesian_virus.append(row)
            
        else:
            dict.append(row)

# %%
for row in dict:
    print (row['id'] + ' ' + row['url'])

# %%
def match_score(A,B):
    if A == B: return 1
    else: return -1

# %%
def print_table(S,header):
    print(header)
    for i in range(0,len(S)):
        print(S[i])
    print('\n')

# %%
# Global Alignment
def complete_global_alignment(v,w):
    m = len(v)
    n = len(w)

    # Backtrack enum
    R_UP = 1
    R_LEFT = 2
    R_DIAG = 3

    d = -1
    S = [[0 for x in range(len(v)+1)] for y in range(len(w)+1)]
    B = [[0 for x in range(len(v)+1)] for y in range(len(w)+1)]

    for i in range(1,len(w)+1):
        S[i][0] = d*i
        B[i][0] = R_UP
    for j in range(1,len(v)+1):
        S[0][j] = d*j
        B[0][j] = R_LEFT
    for i in range(1,len(w)+1):
        for j in range(1,len(v)+1):
            match_score = 1 if v[j-1] == w[i-1] else -1
            Match = S[i-1][j-1] + match_score
            Insert = S[i-1][j] + d
            Delete = S[i][j-1] + d
            S[i][j] = max(Match, Insert, Delete)
            if S[i][j] == Match:
                B[i][j] = R_DIAG
            elif S[i][j] == Insert:
                B[i][j] = R_UP
            elif S[i][j] == Delete:
                B[i][j] = R_LEFT
    
    # Print resulting table
    #print_table(S,'Resulting Table')
    
    # Print backtrack matrix
    #print_table(B,'Backtrack Matrix')
    
    # Print resulting string
    #print('Backtrack Process')
    vr = ""
    wr = ""
    i = n
    j = m
    k = 0
    while B[i][j] != 0:
        if B[i][j] == R_DIAG:
            vr = v[j-1] + vr
            wr = w[i-1] + wr
            #print(i,j,'DIAG')
            i = i-1
            j = j-1
        elif B[i][j] == R_LEFT:
            wr = '-' + wr
            vr = v[j-1] + vr
            #print(i,j,'LEFT')
            j = j-1
        elif B[i][j] == R_UP:
            vr = '-' + vr
            wr = w[i-1] + wr
            #print(i,j,'UP')
            i = i-1

    #print('\n')
    
    #print('Global Alignment')
    #print('Length v:')
    #print(len(vr))
    #print('Length w:')
    #print(len(wr))
    #print(vr)
    #print(wr)
    #print('Score:')
    #print(S[len(w)][len(v)])
    return S[len(w)][len(v)]

# %%
# Global Alignment
def global_alignment(v,w):
    m = len(v)
    n = len(w)

    d = -1
    S = [[0 for x in range(len(v)+1)] for y in range(len(w)+1)]

    for i in range(1,len(w)+1):
        S[i][0] = d*i
    for j in range(1,len(v)+1):
        S[0][j] = d*j
    for i in range(1,len(w)+1):
        for j in range(1,len(v)+1):
            match_score = 1 if v[j-1] == w[i-1] else -1
            Match = S[i-1][j-1] + match_score
            Insert = S[i-1][j] + d
            Delete = S[i][j-1] + d
            S[i][j] = max(Match, Insert, Delete)
                
    return S[len(w)][len(v)]

# %%
def complete_local_alignment(v,w):
    m = len(v)
    n = len(w)

    # Backtrack enum
    R_UP = 1
    R_LEFT = 2
    R_DIAG = 3

    d = -1
    max_val = -1
    max_row = 0
    max_col = 0
    S = [[0 for x in range(len(v)+1)] for y in range(len(w)+1)]
    B = [[0 for x in range(len(v)+1)] for y in range(len(w)+1)]

    for i in range(1,len(w)+1):
        for j in range(1,len(v)+1):
            match_score = 1 if v[j-1] == w[i-1] else -1
            Match = S[i-1][j-1] + match_score
            Insert = S[i-1][j] + d
            Delete = S[i][j-1] + d
            S[i][j] = max(Match, Insert, Delete, 0)
            if S[i][j] > max_val:
                max_val = S[i][j]
                max_row = i
                max_col = j
            if S[i][j] == 0:
                continue
            elif S[i][j] == Match:
                B[i][j] = R_DIAG
            elif S[i][j] == Insert:
                B[i][j] = R_UP
            elif S[i][j] == Delete:
                B[i][j] = R_LEFT

    # Print resulting table
    #print_table(S,'Resulting Table')
          
    # Print backtrack matrix
    #print_table(B,'Backtrack Matrix')
    
    # Print resulting string
    #print('Backtrack Process')
    vr = ""
    wr = ""
    i = max_row
    j = max_col
    #print('Max Row',max_row,'Max Col',max_col)
    while B[i][j] > 0:
        if B[i][j] == R_DIAG:
            vr = v[j-1] + vr
            wr = w[i-1] + wr
            #print(i,j,'DIAG')
            i = i-1
            j = j-1
        elif B[i][j] == R_LEFT:
            #wr = '-' + wr
            vr = v[j-1] + vr
            #print(i,j,'LEFT')
            j = j-1
        elif B[i][j] == R_UP:
            #vr = '-' + vr
            wr = w[i-1] + wr
            #print(i,j,'UP')
            i = i-1

    #print('\n')
    
    #print('Local Alignment')
    #print('Length v:')
    #print(len(vr))
    #print('Length w:')
    #print(len(wr))
    #print(vr)
    #print(wr)
    #vx = vr
    #wx = wr
    #print('Score:')
    #print(max_val)
    #return vr,wr
    return max_val

# %%
def local_alignment(v,w):
    m = len(v)
    n = len(w)

    d = -1
    max_val = -1
    max_row = 0
    max_col = 0
    S = [[0 for x in range(len(v)+1)] for y in range(len(w)+1)]

    for i in range(1,len(w)+1):
        for j in range(1,len(v)+1):
            match_score = 1 if v[j-1] == w[i-1] else -1
            Match = S[i-1][j-1] + match_score
            Insert = S[i-1][j] + d
            Delete = S[i][j-1] + d
            S[i][j] = max(Match, Insert, Delete, 0)
            if S[i][j] > max_val:
                max_val = S[i][j]

    return max_val

# %%
#get centroid
seq_len_kmeans = [[len(row['seq'])] for row in dict]
seq_centroid, seq_cluster, seq_cluster_error = k_means(seq_len_kmeans, n_clusters=2)
seq_centroid
# Out:
# array([[   904.32666667],
#        [ 10614.50588235]])

# %%
#get threshold: the average of centroids
threshold = (seq_centroid[0] + seq_centroid[1])/2
threshold
# Out:
# array([ 5759.41627451])

# %%
len(indonesian_virus[0]['seq'])
# Out:
# 1148

# %%
len(dict[2]['seq'])
# Out:
# 10735

# %%
#individual check
start_time = time.time() # execution time
score = local_alignment(indonesian_virus[0]['seq'],dict[2]['seq'])
print(score)
print("Time elapsed: %s seconds" % (time.time() - start_time))
# Out:
# 556
# Time elapsed: 21.93324899673462 seconds

# %%
#individual check
start_time = time.time() # execution time
v = str(indonesian_virus[0]['seq'])
w = str(dict[2]['seq'])
score = local_alignment(v,w)
print(score)
print("Time elapsed: %s seconds" % (time.time() - start_time))
# Out:
# 556
# Time elapsed: 13.243183135986328 seconds

# %%
#individual check
start_time = time.time() # execution time
v = str(indonesian_virus[0]['seq'])
w = str(dict[2]['seq'])
score = local_alignment(v,w)
print(score)
print("Time elapsed: %s seconds" % (time.time() - start_time))
# Out:
# 556
# Time elapsed: 17.191015005111694 seconds

# %%
#group check
start_time = time.time() # execution time
score = []
i = 1
for ind in indonesian_virus:
    for row in dict:
        print(i)
        virus_time = time.time();
        if ind['id'] == row['id']:
            continue
        print(ind['id'] , ' vs ' , row['id'])
        i += 1
        s = ""
        if len(row['seq']) > threshold:
            print('Local')
            s = local_alignment(ind['seq'],row['seq'])
        else:
            print('Global')
            s = global_alignment(ind['seq'],row['seq'])
        score.append(s)
        print('Score: ' , s)
        print("Time elapsed: %s seconds" % (time.time() - virus_time))
        if i > 10: #Flow control to test
            break
print("Total time elapsed: %s seconds" % (time.time() - start_time))
# Out:
# 1
# KU179098.1  vs  KX101066.1
# Local
# Score:  290
# Time elapsed: 21.58214497566223 seconds
# 2
# KU179098.1  vs  KX101065.1
# Local
# Score:  180
# Time elapsed: 21.251593112945557 seconds
# 3
# KU179098.1  vs  KX101064.1
# Local
# Score:  556
# Time elapsed: 22.33268404006958 seconds
# 4
# KU179098.1  vs  KX101063.1
# Local
# Score:  135
# Time elapsed: 21.783394813537598 seconds
# 5
# KU179098.1  vs  KX101062.1
# Local
# Score:  178
# Time elapsed: 21.886754989624023 seconds
# 6
# KU179098.1  vs  KX101061.1
# Local
# Score:  694
# Time elapsed: 23.080465078353882 seconds
# 7
# KU179098.1  vs  KX101060.1
# Local
# Score:  924
# Time elapsed: 21.181591987609863 seconds
# 8
# KU179098.1  vs  KX377337.1
# Local
# Score:  1126
# Time elapsed: 24.648312091827393 seconds
# 9
# KU179098.1  vs  KX377336.1
# Local
# Score:  1035
# Time elapsed: 26.91932702064514 seconds
# 10
# KU179098.1  vs  KX377335.1
# Local
# Score:  888
# Time elapsed: 27.83112382888794 seconds
# 11
# KF258813.1  vs  KX101066.1
# Local
# Score:  80
# Time elapsed: 8.472402095794678 seconds
# Total time elapsed: 240.97029399871826 seconds

# %%
#write result.txt
start_time = time.time() # execution time
result = ""

for indo in indonesian_virus:
    for foreign in dict:
        virus_time = time.time()
        score = ""
        alignment = ""
        
        if len(foreign['seq']) > threshold:
            alignment = "Local"
            score = local_alignment(indo['seq'], foreign['seq'])
        else:
            alignment = "Global"
            score = global_alignment(indo['seq'], foreign['seq'])
        
        location = foreign['location']
        elapsed_time = time.time() - virus_time
        
        result += (indo['id'] + "|" + foreign['id'] + "|" + location + "|" + alignment + "|" + str(score) + "|" + str(elapsed_time) + "\n")

print("Total time elapsed: %s seconds" % (time.time() - start_time))
f = open('result.txt','w')
f.write(result)
f.close()
# Out:
# Total time elapsed: 2845.6476559638977 seconds

# %%
#read result.txt
f = open("result.txt","r")
lines = f.readlines()
f.close()

result = []

for line in lines:
    line_split = line.split('|')
    detail = {
        'indo'        : line_split[0],
        'foreign'     : line_split[1],
        'location'    : line_split[2],
        'alignment'   : line_split[3],
        'score'       : float(line_split[4]),
        'elapsed_time': float(line_split[5])
    }
    result.append(detail)

# %%
#split the virus
first_virus = result[:int(len(result)/2)]
second_virus = result[int(len(result)/2):]

# %%
#sort the result
sorted_first = sorted(first_virus, key=lambda x: x['score'], reverse=True)
sorted_second = sorted(second_virus, key=lambda x: x['score'], reverse=True)

# %%
sorted_first
# Out:
# [{'alignment': 'Local',
#   'elapsed_time': 20.73088312149048,
#   'foreign': 'KF993678.1',
#   'indo': 'KU179098.1',
#   'location': 'Canada',
#   'score': 1132.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.11390495300293,
#   'foreign': 'KU509998.3',
#   'indo': 'KU179098.1',
#   'location': 'Haiti',
#   'score': 1130.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.34393882751465,
#   'foreign': 'KX051563.1',
#   'indo': 'KU179098.1',
#   'location': 'USA',
#   'score': 1130.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.06683921813965,
#   'foreign': 'KJ776791.1',
#   'indo': 'KU179098.1',
#   'location': 'French Polynesia',
#   'score': 1130.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.96515679359436,
#   'foreign': 'KU647676.1',
#   'indo': 'KU179098.1',
#   'location': 'Martinique',
#   'score': 1128.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.00878381729126,
#   'foreign': 'KU497555.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1128.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.055214881896973,
#   'foreign': 'KU501217.1',
#   'indo': 'KU179098.1',
#   'location': 'Guatemala',
#   'score': 1128.0},
#  {'alignment': 'Local',
#   'elapsed_time': 20.91147017478943,
#   'foreign': 'KU501216.1',
#   'indo': 'KU179098.1',
#   'location': 'Guatemala',
#   'score': 1128.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.10396981239319,
#   'foreign': 'KX377337.1',
#   'indo': 'KU179098.1',
#   'location': 'Puerto Rico',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.082964181900024,
#   'foreign': 'KU820897.3',
#   'indo': 'KU179098.1',
#   'location': 'Colombia',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.10782504081726,
#   'foreign': 'KX280026.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.852696895599365,
#   'foreign': 'KX262887.1',
#   'indo': 'KU179098.1',
#   'location': 'Honduras',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.42418599128723,
#   'foreign': 'KX247646.1',
#   'indo': 'KU179098.1',
#   'location': 'Colombia',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.27303695678711,
#   'foreign': 'KX087101.2',
#   'indo': 'KU179098.1',
#   'location': 'Puerto Rico',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.105338096618652,
#   'foreign': 'KX197192.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.05552387237549,
#   'foreign': 'KX156776.1',
#   'indo': 'KU179098.1',
#   'location': 'Panama',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.758676052093506,
#   'foreign': 'KX156775.1',
#   'indo': 'KU179098.1',
#   'location': 'Panama',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.841193914413452,
#   'foreign': 'KX156774.1',
#   'indo': 'KU179098.1',
#   'location': 'Panama',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.883694171905518,
#   'foreign': 'KX087102.1',
#   'indo': 'KU179098.1',
#   'location': 'Colombia',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.13660192489624,
#   'foreign': 'KU321639.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.095887899398804,
#   'foreign': 'KU870645.1',
#   'indo': 'KU179098.1',
#   'location': 'USA',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.01477813720703,
#   'foreign': 'KU926310.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.90247392654419,
#   'foreign': 'KU501215.1',
#   'indo': 'KU179098.1',
#   'location': 'Puerto Rico',
#   'score': 1126.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.193634033203125,
#   'foreign': 'KU758877.1',
#   'indo': 'KU179098.1',
#   'location': 'French Guiana',
#   'score': 1124.0},
#  {'alignment': 'Local',
#   'elapsed_time': 23.347597122192383,
#   'foreign': 'KX247632.1',
#   'indo': 'KU179098.1',
#   'location': 'Mexico',
#   'score': 1124.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.86012601852417,
#   'foreign': 'KX198135.1',
#   'indo': 'KU179098.1',
#   'location': 'Panama',
#   'score': 1124.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.756112098693848,
#   'foreign': 'KU991811.1',
#   'indo': 'KU179098.1',
#   'location': 'Italy',
#   'score': 1124.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.36835813522339,
#   'foreign': 'KU926309.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1124.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.645641088485718,
#   'foreign': 'KU922960.1',
#   'indo': 'KU179098.1',
#   'location': 'Mexico',
#   'score': 1124.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.692606925964355,
#   'foreign': 'KU922923.1',
#   'indo': 'KU179098.1',
#   'location': 'Mexico',
#   'score': 1124.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.050436973571777,
#   'foreign': 'KU853013.1',
#   'indo': 'KU179098.1',
#   'location': 'Italy',
#   'score': 1124.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.794730186462402,
#   'foreign': 'KU853012.1',
#   'indo': 'KU179098.1',
#   'location': 'Italy',
#   'score': 1124.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.72817087173462,
#   'foreign': 'KU729217.2',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1124.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.132318019866943,
#   'foreign': 'KU527068.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1124.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.39422607421875,
#   'foreign': 'KX117076.1',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1122.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.8476459980011,
#   'foreign': 'KU940228.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1122.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.6828191280365,
#   'foreign': 'KU940224.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1122.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.17987608909607,
#   'foreign': 'KU820898.1',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1122.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.991545915603638,
#   'foreign': 'KU707826.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1122.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.04663109779358,
#   'foreign': 'KU365780.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1122.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.812649965286255,
#   'foreign': 'KU365779.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1122.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.933340072631836,
#   'foreign': 'KU365777.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1122.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.178623914718628,
#   'foreign': 'KU312312.1',
#   'indo': 'KU179098.1',
#   'location': 'Suriname',
#   'score': 1122.0},
#  {'alignment': 'Local',
#   'elapsed_time': 20.977044105529785,
#   'foreign': 'KU866423.2',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1120.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.664139986038208,
#   'foreign': 'KX253996.1',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1120.0},
#  {'alignment': 'Local',
#   'elapsed_time': 20.99010992050171,
#   'foreign': 'KX185891.1',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1120.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.926067113876343,
#   'foreign': 'KU937936.1',
#   'indo': 'KU179098.1',
#   'location': 'Suriname',
#   'score': 1120.0},
#  {'alignment': 'Local',
#   'elapsed_time': 20.969670057296753,
#   'foreign': 'KX056898.1',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1120.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.884455919265747,
#   'foreign': 'KU955590.1',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1120.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.6480131149292,
#   'foreign': 'KU955589.1',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1120.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.943190097808838,
#   'foreign': 'KU963796.1',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1120.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.610942840576172,
#   'foreign': 'KU740184.2',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1120.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.062366008758545,
#   'foreign': 'KU820899.2',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1120.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.184102058410645,
#   'foreign': 'KU729218.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1120.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.251227140426636,
#   'foreign': 'KU761564.1',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1120.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.89665198326111,
#   'foreign': 'KU365778.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 1118.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.646092891693115,
#   'foreign': 'KU955593.1',
#   'indo': 'KU179098.1',
#   'location': 'Cambodia',
#   'score': 1116.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.521780967712402,
#   'foreign': 'KU681081.3',
#   'indo': 'KU179098.1',
#   'location': 'Thailand',
#   'score': 1116.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.02849006652832,
#   'foreign': 'JN860885.1',
#   'indo': 'KU179098.1',
#   'location': 'Cambodia',
#   'score': 1116.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.813657999038696,
#   'foreign': 'KU744693.1',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': 1114.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.281747102737427,
#   'foreign': 'EU545988.1',
#   'indo': 'KU179098.1',
#   'location': 'Micronesia',
#   'score': 1110.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.817123889923096,
#   'foreign': 'KU681082.3',
#   'indo': 'KU179098.1',
#   'location': 'Philippines',
#   'score': 1100.0},
#  {'alignment': 'Local',
#   'elapsed_time': 20.944031953811646,
#   'foreign': 'HQ234499.1',
#   'indo': 'KU179098.1',
#   'location': 'Malaysia',
#   'score': 1037.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.061814069747925,
#   'foreign': 'KX377336.1',
#   'indo': 'KU179098.1',
#   'location': 'Malaysia',
#   'score': 1035.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.37630796432495,
#   'foreign': 'KX101060.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 924.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.79842495918274,
#   'foreign': 'KX198134.1',
#   'indo': 'KU179098.1',
#   'location': 'Senegal',
#   'score': 891.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.416754961013794,
#   'foreign': 'KX377335.1',
#   'indo': 'KU179098.1',
#   'location': 'Uganda',
#   'score': 888.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.341810941696167,
#   'foreign': 'KU955594.1',
#   'indo': 'KU179098.1',
#   'location': 'Uganda',
#   'score': 888.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.099472045898438,
#   'foreign': 'KU963573.1',
#   'indo': 'KU179098.1',
#   'location': 'Uganda',
#   'score': 888.0},
#  {'alignment': 'Local',
#   'elapsed_time': 20.951415061950684,
#   'foreign': 'HQ234498.1',
#   'indo': 'KU179098.1',
#   'location': 'Uganda',
#   'score': 888.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.228258848190308,
#   'foreign': 'KU955595.1',
#   'indo': 'KU179098.1',
#   'location': 'Senegal',
#   'score': 887.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.256867170333862,
#   'foreign': 'KU955591.1',
#   'indo': 'KU179098.1',
#   'location': 'Senegal',
#   'score': 887.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.19976496696472,
#   'foreign': 'KU955592.1',
#   'indo': 'KU179098.1',
#   'location': 'Senegal',
#   'score': 885.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.376687049865723,
#   'foreign': 'KF268948.1',
#   'indo': 'KU179098.1',
#   'location': 'Central African Republic',
#   'score': 882.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.003116846084595,
#   'foreign': 'HQ234501.1',
#   'indo': 'KU179098.1',
#   'location': 'Senegal',
#   'score': 877.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.31342101097107,
#   'foreign': 'KU963574.1',
#   'indo': 'KU179098.1',
#   'location': 'Nigeria',
#   'score': 873.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.273545026779175,
#   'foreign': 'HQ234500.1',
#   'indo': 'KU179098.1',
#   'location': 'Nigeria',
#   'score': 873.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.9624440670013428,
#   'foreign': 'KX059014.1',
#   'indo': 'KU179098.1',
#   'location': 'Haiti',
#   'score': 778.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.9618799686431885,
#   'foreign': 'KX059013.1',
#   'indo': 'KU179098.1',
#   'location': 'Haiti',
#   'score': 778.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8658108711242676,
#   'foreign': 'KM078979.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8723750114440918,
#   'foreign': 'KM078978.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8708858489990234,
#   'foreign': 'KM078976.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8683290481567383,
#   'foreign': 'KM078975.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.867828130722046,
#   'foreign': 'KM078973.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8718619346618652,
#   'foreign': 'KM078969.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8778200149536133,
#   'foreign': 'KM078967.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.864414930343628,
#   'foreign': 'KM078966.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.860307216644287,
#   'foreign': 'KM078965.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8638288974761963,
#   'foreign': 'KM078964.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8668699264526367,
#   'foreign': 'KM078963.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8738231658935547,
#   'foreign': 'KM078962.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8703501224517822,
#   'foreign': 'KM078960.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8683140277862549,
#   'foreign': 'KM078958.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8768529891967773,
#   'foreign': 'KM078957.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8783371448516846,
#   'foreign': 'KM078955.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8633267879486084,
#   'foreign': 'KM078953.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8698151111602783,
#   'foreign': 'KM078952.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8638269901275635,
#   'foreign': 'KM078951.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8698511123657227,
#   'foreign': 'KM078950.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8738608360290527,
#   'foreign': 'KM078949.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8683581352233887,
#   'foreign': 'KM078948.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.994575023651123,
#   'foreign': 'KM078947.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.988954782485962,
#   'foreign': 'KM078946.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.9764091968536377,
#   'foreign': 'KM078945.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8703320026397705,
#   'foreign': 'KM078943.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8643290996551514,
#   'foreign': 'KM078941.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8693699836730957,
#   'foreign': 'KM078940.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.9313750267028809,
#   'foreign': 'KM078939.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8658289909362793,
#   'foreign': 'KM078938.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8728351593017578,
#   'foreign': 'KM078936.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 760.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8668491840362549,
#   'foreign': 'KM078977.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 758.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.85984206199646,
#   'foreign': 'KM078968.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 758.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8658277988433838,
#   'foreign': 'KM078961.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 758.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8658130168914795,
#   'foreign': 'KM078956.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 758.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8709440231323242,
#   'foreign': 'KM078954.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 758.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8693318367004395,
#   'foreign': 'KM078944.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 758.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8688321113586426,
#   'foreign': 'KM078942.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 758.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8708508014678955,
#   'foreign': 'KM078937.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 758.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.87481689453125,
#   'foreign': 'KM078935.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 758.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8733351230621338,
#   'foreign': 'KM078934.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 758.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8693311214447021,
#   'foreign': 'KM078932.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 758.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8738338947296143,
#   'foreign': 'KM078930.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 758.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.866832971572876,
#   'foreign': 'KM078974.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 756.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8663299083709717,
#   'foreign': 'KM078972.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 756.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8743350505828857,
#   'foreign': 'KM078971.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 756.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.870832920074463,
#   'foreign': 'KM078970.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 756.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8573598861694336,
#   'foreign': 'KM078959.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 756.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8688318729400635,
#   'foreign': 'KM078933.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 756.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8733489513397217,
#   'foreign': 'KM078931.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 756.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.872373104095459,
#   'foreign': 'KM078929.1',
#   'indo': 'KU179098.1',
#   'location': 'Chile',
#   'score': 756.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.585103034973145,
#   'foreign': 'KX101061.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 694.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.709280014038086,
#   'foreign': 'KJ873160.1',
#   'indo': 'KU179098.1',
#   'location': 'New Caledonia',
#   'score': 624.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.858248949050903,
#   'foreign': 'KX101064.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 556.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.54796600341797,
#   'foreign': 'KU940227.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 438.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.5165789127349854,
#   'foreign': 'KJ873161.1',
#   'indo': 'KU179098.1',
#   'location': 'New Caledonia',
#   'score': 422.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.533556938171387,
#   'foreign': 'KX101067.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 370.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.4395270347595215,
#   'foreign': 'KU985087.1',
#   'indo': 'KU179098.1',
#   'location': 'Mexico',
#   'score': 346.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.481114149093628,
#   'foreign': 'KU556802.1',
#   'indo': 'KU179098.1',
#   'location': 'Mexico',
#   'score': 336.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.508594036102295,
#   'foreign': 'KM851039.1',
#   'indo': 'KU179098.1',
#   'location': 'Thailand',
#   'score': 312.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.5026111602783203,
#   'foreign': 'KM851038.1',
#   'indo': 'KU179098.1',
#   'location': 'Philippines',
#   'score': 300.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.3864879608154297,
#   'foreign': 'KU724096.1',
#   'indo': 'KU179098.1',
#   'location': 'Panama',
#   'score': 292.0},
#  {'alignment': 'Local',
#   'elapsed_time': 22.15080499649048,
#   'foreign': 'KX101066.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 290.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.31597900390625,
#   'foreign': 'KU232297.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 224.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.3204431533813477,
#   'foreign': 'KU232301.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 222.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.3214259147644043,
#   'foreign': 'KU232300.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 222.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.3059301376342773,
#   'foreign': 'KU232290.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 216.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.3099510669708252,
#   'foreign': 'KU232292.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 202.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.290902853012085,
#   'foreign': 'KU232294.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 198.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.2889020442962646,
#   'foreign': 'KU232298.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 196.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.296422004699707,
#   'foreign': 'KU232293.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 196.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.2939038276672363,
#   'foreign': 'KU232296.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 192.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.284433126449585,
#   'foreign': 'KU232295.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 184.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.067865133285522,
#   'foreign': 'KX101065.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 180.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.028167963027954,
#   'foreign': 'KX101062.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 178.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.2648839950561523,
#   'foreign': 'KU232291.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 172.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.2654139995574951,
#   'foreign': 'KU232288.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 170.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.2574388980865479,
#   'foreign': 'KU232289.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 166.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.264456033706665,
#   'foreign': 'KU232299.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 162.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.248934030532837,
#   'foreign': 'KU724097.1',
#   'indo': 'KU179098.1',
#   'location': 'Panama',
#   'score': 150.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.2389769554138184,
#   'foreign': 'KU724098.1',
#   'indo': 'KU179098.1',
#   'location': 'Panama',
#   'score': 138.0},
#  {'alignment': 'Local',
#   'elapsed_time': 21.62235713005066,
#   'foreign': 'KX101063.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 135.0},
#  {'alignment': 'Global',
#   'elapsed_time': 2.465794086456299,
#   'foreign': 'KU686218.1',
#   'indo': 'KU179098.1',
#   'location': 'Mexico',
#   'score': 116.0},
#  {'alignment': 'Global',
#   'elapsed_time': 2.921604871749878,
#   'foreign': 'KJ634273.1',
#   'indo': 'KU179098.1',
#   'location': 'Cook Islands',
#   'score': 74.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.1723370552062988,
#   'foreign': 'KU724099.1',
#   'indo': 'KU179098.1',
#   'location': 'Panama',
#   'score': 70.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.7697601318359375,
#   'foreign': 'KX173841.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 65.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.77878999710083,
#   'foreign': 'KX173840.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 65.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.6116468906402588,
#   'foreign': 'KX173844.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 50.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.6226751804351807,
#   'foreign': 'KX173843.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': 50.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.610685110092163,
#   'foreign': 'KF270886.1',
#   'indo': 'KU179098.1',
#   'location': 'Gabon',
#   'score': 45.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.48207688331604,
#   'foreign': 'KF270887.1',
#   'indo': 'KU179098.1',
#   'location': 'Gabon',
#   'score': -13.0},
#  {'alignment': 'Global',
#   'elapsed_time': 3.481595993041992,
#   'foreign': 'KU740199.1',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': -59.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.3460328578948975,
#   'foreign': 'KT200609.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': -67.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.0007128715515137,
#   'foreign': 'KU724100.1',
#   'indo': 'KU179098.1',
#   'location': 'Panama',
#   'score': -100.0},
#  {'alignment': 'Global',
#   'elapsed_time': 3.702247142791748,
#   'foreign': 'KU312315.1',
#   'indo': 'KU179098.1',
#   'location': 'Suriname',
#   'score': -103.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.2528979778289795,
#   'foreign': 'KU758878.1',
#   'indo': 'KU179098.1',
#   'location': 'Thailand',
#   'score': -104.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.0742838382720947,
#   'foreign': 'KU867812.1',
#   'indo': 'KU179098.1',
#   'location': 'China',
#   'score': -179.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.8436009883880615,
#   'foreign': 'KX253994.1',
#   'indo': 'KU179098.1',
#   'location': 'Germany',
#   'score': -260.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.9461560249328613,
#   'foreign': 'KX247638.1',
#   'indo': 'KU179098.1',
#   'location': 'Russia',
#   'score': -283.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.9406578540802002,
#   'foreign': 'KU978616.1',
#   'indo': 'KU179098.1',
#   'location': 'Russia',
#   'score': -284.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.8936519622802734,
#   'foreign': 'AB908162.1',
#   'indo': 'KU179098.1',
#   'location': 'French Polynesia',
#   'score': -311.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.8781580924987793,
#   'foreign': 'KU872850.1',
#   'indo': 'KU179098.1',
#   'location': 'Russia',
#   'score': -324.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.7184929847717285,
#   'foreign': 'KX253995.1',
#   'indo': 'KU179098.1',
#   'location': 'Germany',
#   'score': -394.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6809790134429932,
#   'foreign': 'KU985088.1',
#   'indo': 'KU179098.1',
#   'location': 'Mexico',
#   'score': -450.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6609690189361572,
#   'foreign': 'KX062045.1',
#   'indo': 'KU179098.1',
#   'location': 'Haiti',
#   'score': -468.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6624908447265625,
#   'foreign': 'KX062044.1',
#   'indo': 'KU179098.1',
#   'location': 'Haiti',
#   'score': -468.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6264288425445557,
#   'foreign': 'KR815990.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': -502.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.62996506690979,
#   'foreign': 'KR815989.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': -502.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6239268779754639,
#   'foreign': 'KX173842.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': -505.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.162917137145996,
#   'foreign': 'KU646827.1',
#   'indo': 'KU179098.1',
#   'location': 'Colombia',
#   'score': -527.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.034113883972168,
#   'foreign': 'KU646828.1',
#   'indo': 'KU179098.1',
#   'location': 'Colombia',
#   'score': -528.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5944130420684814,
#   'foreign': 'KR816336.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': -532.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5844159126281738,
#   'foreign': 'KR816334.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': -532.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5854160785675049,
#   'foreign': 'KR816333.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': -532.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5839099884033203,
#   'foreign': 'KR816335.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': -534.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5629010200500488,
#   'foreign': 'KM212967.1',
#   'indo': 'KU179098.1',
#   'location': 'New Caledonia',
#   'score': -558.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5613999366760254,
#   'foreign': 'KM212966.1',
#   'indo': 'KU179098.1',
#   'location': 'New Caledonia',
#   'score': -558.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5604119300842285,
#   'foreign': 'KM212965.1',
#   'indo': 'KU179098.1',
#   'location': 'New Caledonia',
#   'score': -558.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5693910121917725,
#   'foreign': 'KM212964.1',
#   'indo': 'KU179098.1',
#   'location': 'New Caledonia',
#   'score': -558.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5619020462036133,
#   'foreign': 'KM212963.1',
#   'indo': 'KU179098.1',
#   'location': 'New Caledonia',
#   'score': -558.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5343990325927734,
#   'foreign': 'KU844090.1',
#   'indo': 'KU179098.1',
#   'location': 'Russia',
#   'score': -586.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5309200286865234,
#   'foreign': 'KP099610.1',
#   'indo': 'KU179098.1',
#   'location': 'Cook Islands',
#   'score': -586.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5343799591064453,
#   'foreign': 'KP099609.1',
#   'indo': 'KU179098.1',
#   'location': 'Cook Islands',
#   'score': -586.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5308609008789062,
#   'foreign': 'KM014700.1',
#   'indo': 'KU179098.1',
#   'location': 'French Polynesia',
#   'score': -586.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5308771133422852,
#   'foreign': 'KJ579442.1',
#   'indo': 'KU179098.1',
#   'location': 'French Polynesia',
#   'score': -586.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5333797931671143,
#   'foreign': 'KJ579441.1',
#   'indo': 'KU179098.1',
#   'location': 'French Polynesia',
#   'score': -586.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5328810214996338,
#   'foreign': 'KJ680135.1',
#   'indo': 'KU179098.1',
#   'location': 'French Polynesia',
#   'score': -586.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5323891639709473,
#   'foreign': 'KJ680134.1',
#   'indo': 'KU179098.1',
#   'location': 'French Polynesia',
#   'score': -586.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4908618927001953,
#   'foreign': 'KX261853.1',
#   'indo': 'KU179098.1',
#   'location': 'Colombia',
#   'score': -638.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4709019660949707,
#   'foreign': 'KX261855.1',
#   'indo': 'KU179098.1',
#   'location': 'Colombia',
#   'score': -662.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4683210849761963,
#   'foreign': 'KX261852.1',
#   'indo': 'KU179098.1',
#   'location': 'Colombia',
#   'score': -664.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4588470458984375,
#   'foreign': 'KX261851.1',
#   'indo': 'KU179098.1',
#   'location': 'Colombia',
#   'score': -664.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.46182894706726074,
#   'foreign': 'KX261854.1',
#   'indo': 'KU179098.1',
#   'location': 'Colombia',
#   'score': -668.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.45181989669799805,
#   'foreign': 'KU954085.1',
#   'indo': 'KU179098.1',
#   'location': 'Colombia',
#   'score': -668.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4483051300048828,
#   'foreign': 'KT381874.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': -672.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.43581080436706543,
#   'foreign': 'KU926326.1',
#   'indo': 'KU179098.1',
#   'location': 'Israel',
#   'score': -686.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4368109703063965,
#   'foreign': 'KU926325.1',
#   'indo': 'KU179098.1',
#   'location': 'Israel',
#   'score': -686.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4373300075531006,
#   'foreign': 'KU926324.1',
#   'indo': 'KU179098.1',
#   'location': 'Israel',
#   'score': -686.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4378070831298828,
#   'foreign': 'KU926323.1',
#   'indo': 'KU179098.1',
#   'location': 'Israel',
#   'score': -686.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4263038635253906,
#   'foreign': 'KM212961.1',
#   'indo': 'KU179098.1',
#   'location': 'New Caledonia',
#   'score': -696.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.434416055679321,
#   'foreign': 'KU312314.1',
#   'indo': 'KU179098.1',
#   'location': 'Suriname',
#   'score': -704.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.466049909591675,
#   'foreign': 'KU312313.1',
#   'indo': 'KU179098.1',
#   'location': 'Suriname',
#   'score': -704.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.446913003921509,
#   'foreign': 'KX212103.1',
#   'indo': 'KU179098.1',
#   'location': 'Brazil',
#   'score': -708.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.498917818069458,
#   'foreign': 'KU758874.1',
#   'indo': 'KU179098.1',
#   'location': 'French Guiana',
#   'score': -717.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.474483013153076,
#   'foreign': 'KU758868.1',
#   'indo': 'KU179098.1',
#   'location': 'French Guiana',
#   'score': -719.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.520971059799194,
#   'foreign': 'KU758869.1',
#   'indo': 'KU179098.1',
#   'location': 'French Guiana',
#   'score': -725.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.592694997787476,
#   'foreign': 'KU758872.1',
#   'indo': 'KU179098.1',
#   'location': 'French Guiana',
#   'score': -733.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.523935079574585,
#   'foreign': 'KU758870.1',
#   'indo': 'KU179098.1',
#   'location': 'French Guiana',
#   'score': -734.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.555483102798462,
#   'foreign': 'KU758876.1',
#   'indo': 'KU179098.1',
#   'location': 'Suriname',
#   'score': -735.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.819758176803589,
#   'foreign': 'KU758873.1',
#   'indo': 'KU179098.1',
#   'location': 'French Guiana',
#   'score': -737.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.542456865310669,
#   'foreign': 'KU758871.1',
#   'indo': 'KU179098.1',
#   'location': 'French Guiana',
#   'score': -737.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.38576292991638184,
#   'foreign': 'KU752545.1',
#   'indo': 'KU179098.1',
#   'location': 'Portugal',
#   'score': -738.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.38832998275756836,
#   'foreign': 'KU752544.1',
#   'indo': 'KU179098.1',
#   'location': 'Portugal',
#   'score': -738.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.3787698745727539,
#   'foreign': 'KJ461621.1',
#   'indo': 'KU179098.1',
#   'location': 'Norway',
#   'score': -746.0},
#  {'alignment': 'Global',
#   'elapsed_time': 5.576472043991089,
#   'foreign': 'KU758875.1',
#   'indo': 'KU179098.1',
#   'location': 'French Guiana',
#   'score': -749.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.3582420349121094,
#   'foreign': 'KX358623.1',
#   'indo': 'KU179098.1',
#   'location': 'Venezuela',
#   'score': -766.0}]

# %%
sorted_second
# Out:
# [{'alignment': 'Local',
#   'elapsed_time': 7.22956109046936,
#   'foreign': 'KF993678.1',
#   'indo': 'KF258813.1',
#   'location': 'Canada',
#   'score': 392.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.226809978485107,
#   'foreign': 'EU545988.1',
#   'indo': 'KF258813.1',
#   'location': 'Micronesia',
#   'score': 392.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.529456853866577,
#   'foreign': 'KX101064.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.186153173446655,
#   'foreign': 'KU866423.2',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.427290916442871,
#   'foreign': 'KU647676.1',
#   'indo': 'KF258813.1',
#   'location': 'Martinique',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.573949098587036,
#   'foreign': 'KX280026.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.594936847686768,
#   'foreign': 'KU955593.1',
#   'indo': 'KF258813.1',
#   'location': 'Cambodia',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.886451959609985,
#   'foreign': 'KU681082.3',
#   'indo': 'KF258813.1',
#   'location': 'Philippines',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.564917087554932,
#   'foreign': 'KX253996.1',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.575952053070068,
#   'foreign': 'KX197192.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.198302984237671,
#   'foreign': 'KX185891.1',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.582000017166138,
#   'foreign': 'KX117076.1',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.561430931091309,
#   'foreign': 'KU509998.3',
#   'indo': 'KF258813.1',
#   'location': 'Haiti',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.559373140335083,
#   'foreign': 'KX051563.1',
#   'indo': 'KF258813.1',
#   'location': 'USA',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.42082405090332,
#   'foreign': 'KU955589.1',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.5023579597473145,
#   'foreign': 'KU963796.1',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.473917007446289,
#   'foreign': 'KU321639.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.495898962020874,
#   'foreign': 'KU940228.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.541451930999756,
#   'foreign': 'KU940227.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.590948104858398,
#   'foreign': 'KU940224.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.584981918334961,
#   'foreign': 'KU926310.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.557425022125244,
#   'foreign': 'KU926309.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.913379907608032,
#   'foreign': 'KU820899.2',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.5649449825286865,
#   'foreign': 'KU497555.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.915374994277954,
#   'foreign': 'KU527068.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.531938791275024,
#   'foreign': 'KJ776791.1',
#   'indo': 'KF258813.1',
#   'location': 'French Polynesia',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.234760999679565,
#   'foreign': 'JN860885.1',
#   'indo': 'KF258813.1',
#   'location': 'Cambodia',
#   'score': 390.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.832887172698975,
#   'foreign': 'KX377337.1',
#   'indo': 'KF258813.1',
#   'location': 'Puerto Rico',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.62744402885437,
#   'foreign': 'KU820897.3',
#   'indo': 'KF258813.1',
#   'location': 'Colombia',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.574927806854248,
#   'foreign': 'KX262887.1',
#   'indo': 'KF258813.1',
#   'location': 'Honduras',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.597913026809692,
#   'foreign': 'KX247646.1',
#   'indo': 'KF258813.1',
#   'location': 'Colombia',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.524856090545654,
#   'foreign': 'KX087101.2',
#   'indo': 'KF258813.1',
#   'location': 'Puerto Rico',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.4998779296875,
#   'foreign': 'KX198135.1',
#   'indo': 'KF258813.1',
#   'location': 'Panama',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.453824996948242,
#   'foreign': 'KX156776.1',
#   'indo': 'KF258813.1',
#   'location': 'Panama',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.476812839508057,
#   'foreign': 'KX156775.1',
#   'indo': 'KF258813.1',
#   'location': 'Panama',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.620597839355469,
#   'foreign': 'KX156774.1',
#   'indo': 'KF258813.1',
#   'location': 'Panama',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.479887008666992,
#   'foreign': 'KX087102.1',
#   'indo': 'KF258813.1',
#   'location': 'Colombia',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.470321893692017,
#   'foreign': 'KU991811.1',
#   'indo': 'KF258813.1',
#   'location': 'Italy',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.572412967681885,
#   'foreign': 'KU870645.1',
#   'indo': 'KF258813.1',
#   'location': 'USA',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.47940993309021,
#   'foreign': 'KU853013.1',
#   'indo': 'KF258813.1',
#   'location': 'Italy',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.4443440437316895,
#   'foreign': 'KU853012.1',
#   'indo': 'KF258813.1',
#   'location': 'Italy',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.486877918243408,
#   'foreign': 'KU729217.2',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.528362989425659,
#   'foreign': 'KU729218.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.2602150440216064,
#   'foreign': 'KU501217.1',
#   'indo': 'KF258813.1',
#   'location': 'Guatemala',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.207204103469849,
#   'foreign': 'KU501216.1',
#   'indo': 'KF258813.1',
#   'location': 'Guatemala',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.498914957046509,
#   'foreign': 'KU501215.1',
#   'indo': 'KF258813.1',
#   'location': 'Puerto Rico',
#   'score': 388.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.255724906921387,
#   'foreign': 'KU758877.1',
#   'indo': 'KF258813.1',
#   'location': 'French Guiana',
#   'score': 386.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.5564329624176025,
#   'foreign': 'KX247632.1',
#   'indo': 'KF258813.1',
#   'location': 'Mexico',
#   'score': 386.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.5724098682403564,
#   'foreign': 'KU681081.3',
#   'indo': 'KF258813.1',
#   'location': 'Thailand',
#   'score': 386.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.439806938171387,
#   'foreign': 'KU922960.1',
#   'indo': 'KF258813.1',
#   'location': 'Mexico',
#   'score': 386.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.450340986251831,
#   'foreign': 'KU922923.1',
#   'indo': 'KF258813.1',
#   'location': 'Mexico',
#   'score': 386.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.209208965301514,
#   'foreign': 'KU820898.1',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 386.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.467849969863892,
#   'foreign': 'KU707826.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 386.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.480341911315918,
#   'foreign': 'KU365780.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 386.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.481356143951416,
#   'foreign': 'KU365779.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 386.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.489893198013306,
#   'foreign': 'KU365777.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 386.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.809347867965698,
#   'foreign': 'KU312312.1',
#   'indo': 'KF258813.1',
#   'location': 'Suriname',
#   'score': 386.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.498355865478516,
#   'foreign': 'KU744693.1',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 384.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.24467396736145,
#   'foreign': 'KX056898.1',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 384.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.692798852920532,
#   'foreign': 'KU955590.1',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 384.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.412312030792236,
#   'foreign': 'KU740184.2',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 384.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.2836830615997314,
#   'foreign': 'KU761564.1',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 384.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.527517795562744,
#   'foreign': 'KU365778.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 384.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.588025093078613,
#   'foreign': 'KU937936.1',
#   'indo': 'KF258813.1',
#   'location': 'Suriname',
#   'score': 382.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.209214925765991,
#   'foreign': 'KX101060.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 378.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.561450004577637,
#   'foreign': 'KX377336.1',
#   'indo': 'KF258813.1',
#   'location': 'Malaysia',
#   'score': 366.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.561146974563599,
#   'foreign': 'HQ234499.1',
#   'indo': 'KF258813.1',
#   'location': 'Malaysia',
#   'score': 366.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.739718914031982,
#   'foreign': 'KX198134.1',
#   'indo': 'KF258813.1',
#   'location': 'Senegal',
#   'score': 306.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.54560399055481,
#   'foreign': 'KU955595.1',
#   'indo': 'KF258813.1',
#   'location': 'Senegal',
#   'score': 304.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.581495046615601,
#   'foreign': 'KU955591.1',
#   'indo': 'KF258813.1',
#   'location': 'Senegal',
#   'score': 304.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.203627109527588,
#   'foreign': 'HQ234501.1',
#   'indo': 'KF258813.1',
#   'location': 'Senegal',
#   'score': 304.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.837184190750122,
#   'foreign': 'KF268948.1',
#   'indo': 'KF258813.1',
#   'location': 'Central African Republic',
#   'score': 303.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.577649116516113,
#   'foreign': 'KU955592.1',
#   'indo': 'KF258813.1',
#   'location': 'Senegal',
#   'score': 302.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.391304016113281,
#   'foreign': 'KX101067.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 299.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.571074962615967,
#   'foreign': 'KX377335.1',
#   'indo': 'KF258813.1',
#   'location': 'Uganda',
#   'score': 296.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.5859479904174805,
#   'foreign': 'KU955594.1',
#   'indo': 'KF258813.1',
#   'location': 'Uganda',
#   'score': 296.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.509848117828369,
#   'foreign': 'KU963573.1',
#   'indo': 'KF258813.1',
#   'location': 'Uganda',
#   'score': 296.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.254711866378784,
#   'foreign': 'HQ234498.1',
#   'indo': 'KF258813.1',
#   'location': 'Uganda',
#   'score': 296.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.300729036331177,
#   'foreign': 'KU963574.1',
#   'indo': 'KF258813.1',
#   'location': 'Nigeria',
#   'score': 290.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.251688003540039,
#   'foreign': 'HQ234500.1',
#   'indo': 'KF258813.1',
#   'location': 'Nigeria',
#   'score': 290.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.201663970947266,
#   'foreign': 'KX101062.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 175.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.2037670612335205,
#   'foreign': 'KX101065.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 148.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.404788017272949,
#   'foreign': 'KX101061.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 145.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.252162933349609,
#   'foreign': 'KX101063.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 133.0},
#  {'alignment': 'Local',
#   'elapsed_time': 7.4523138999938965,
#   'foreign': 'KX101066.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 80.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.24568700790405273,
#   'foreign': 'KX253995.1',
#   'indo': 'KF258813.1',
#   'location': 'Germany',
#   'score': 39.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.3067138195037842,
#   'foreign': 'AB908162.1',
#   'indo': 'KF258813.1',
#   'location': 'French Polynesia',
#   'score': 37.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.29169583320617676,
#   'foreign': 'KX253994.1',
#   'indo': 'KF258813.1',
#   'location': 'Germany',
#   'score': 35.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.22713398933410645,
#   'foreign': 'KX062044.1',
#   'indo': 'KF258813.1',
#   'location': 'Haiti',
#   'score': 31.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.2271890640258789,
#   'foreign': 'KX062045.1',
#   'indo': 'KF258813.1',
#   'location': 'Haiti',
#   'score': 30.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.2327408790588379,
#   'foreign': 'KU985088.1',
#   'indo': 'KF258813.1',
#   'location': 'Mexico',
#   'score': 28.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.3457460403442383,
#   'foreign': 'KU724100.1',
#   'indo': 'KF258813.1',
#   'location': 'Panama',
#   'score': 26.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.21671104431152344,
#   'foreign': 'KR815990.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 18.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.2196509838104248,
#   'foreign': 'KR815989.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 18.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.21465206146240234,
#   'foreign': 'KX173842.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 17.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.370258092880249,
#   'foreign': 'KU867812.1',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': 16.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.3007330894470215,
#   'foreign': 'KU872850.1',
#   'indo': 'KF258813.1',
#   'location': 'Russia',
#   'score': 15.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.20113015174865723,
#   'foreign': 'KR816336.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 12.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.20418286323547363,
#   'foreign': 'KR816334.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 12.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.2086319923400879,
#   'foreign': 'KR816333.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 12.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.32074594497680664,
#   'foreign': 'KX247638.1',
#   'indo': 'KF258813.1',
#   'location': 'Russia',
#   'score': 10.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.32471704483032227,
#   'foreign': 'KU978616.1',
#   'indo': 'KF258813.1',
#   'location': 'Russia',
#   'score': 10.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.20316195487976074,
#   'foreign': 'KR816335.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': 9.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.19365406036376953,
#   'foreign': 'KM212967.1',
#   'indo': 'KF258813.1',
#   'location': 'New Caledonia',
#   'score': 2.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.19662714004516602,
#   'foreign': 'KM212965.1',
#   'indo': 'KF258813.1',
#   'location': 'New Caledonia',
#   'score': 2.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.19415593147277832,
#   'foreign': 'KM212964.1',
#   'indo': 'KF258813.1',
#   'location': 'New Caledonia',
#   'score': 1.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.1941509246826172,
#   'foreign': 'KM212966.1',
#   'indo': 'KF258813.1',
#   'location': 'New Caledonia',
#   'score': 0.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.19262099266052246,
#   'foreign': 'KM212963.1',
#   'indo': 'KF258813.1',
#   'location': 'New Caledonia',
#   'score': -1.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.18562102317810059,
#   'foreign': 'KP099610.1',
#   'indo': 'KF258813.1',
#   'location': 'Cook Islands',
#   'score': -6.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.18364286422729492,
#   'foreign': 'KP099609.1',
#   'indo': 'KF258813.1',
#   'location': 'Cook Islands',
#   'score': -6.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.183135986328125,
#   'foreign': 'KJ680135.1',
#   'indo': 'KF258813.1',
#   'location': 'French Polynesia',
#   'score': -6.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.18361306190490723,
#   'foreign': 'KJ680134.1',
#   'indo': 'KF258813.1',
#   'location': 'French Polynesia',
#   'score': -6.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.18163490295410156,
#   'foreign': 'KU844090.1',
#   'indo': 'KF258813.1',
#   'location': 'Russia',
#   'score': -8.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.18313193321228027,
#   'foreign': 'KM014700.1',
#   'indo': 'KF258813.1',
#   'location': 'French Polynesia',
#   'score': -8.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.18312597274780273,
#   'foreign': 'KJ579442.1',
#   'indo': 'KF258813.1',
#   'location': 'French Polynesia',
#   'score': -8.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.18412995338439941,
#   'foreign': 'KJ579441.1',
#   'indo': 'KF258813.1',
#   'location': 'French Polynesia',
#   'score': -8.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.1331009864807129,
#   'foreign': 'KU752544.1',
#   'indo': 'KF258813.1',
#   'location': 'Portugal',
#   'score': -10.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.13361406326293945,
#   'foreign': 'KU752545.1',
#   'indo': 'KF258813.1',
#   'location': 'Portugal',
#   'score': -12.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4032878875732422,
#   'foreign': 'KU724099.1',
#   'indo': 'KF258813.1',
#   'location': 'Panama',
#   'score': -15.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.16609621047973633,
#   'foreign': 'KX261853.1',
#   'indo': 'KF258813.1',
#   'location': 'Colombia',
#   'score': -17.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4343268871307373,
#   'foreign': 'KU232299.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -17.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.43280887603759766,
#   'foreign': 'KU232289.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -19.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.43730998039245605,
#   'foreign': 'KU232291.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -21.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.43581104278564453,
#   'foreign': 'KU232288.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -21.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.44429993629455566,
#   'foreign': 'KU232295.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -26.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.42830395698547363,
#   'foreign': 'KU724097.1',
#   'indo': 'KF258813.1',
#   'location': 'Panama',
#   'score': -27.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.15761208534240723,
#   'foreign': 'KX261855.1',
#   'indo': 'KF258813.1',
#   'location': 'Colombia',
#   'score': -27.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.42830514907836914,
#   'foreign': 'KU724098.1',
#   'indo': 'KF258813.1',
#   'location': 'Panama',
#   'score': -28.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4438331127166748,
#   'foreign': 'KU232296.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -29.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4268040657043457,
#   'foreign': 'KU758878.1',
#   'indo': 'KF258813.1',
#   'location': 'Thailand',
#   'score': -30.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.444317102432251,
#   'foreign': 'KU232298.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -30.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4463350772857666,
#   'foreign': 'KU232294.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -30.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.44479990005493164,
#   'foreign': 'KU232293.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -30.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4478189945220947,
#   'foreign': 'KU232292.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -31.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.451322078704834,
#   'foreign': 'KU232290.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -33.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.1566329002380371,
#   'foreign': 'KX261854.1',
#   'indo': 'KF258813.1',
#   'location': 'Colombia',
#   'score': -34.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.45432186126708984,
#   'foreign': 'KU232301.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -34.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4533231258392334,
#   'foreign': 'KU232300.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -34.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.15661287307739258,
#   'foreign': 'KX261852.1',
#   'indo': 'KF258813.1',
#   'location': 'Colombia',
#   'score': -35.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.15665411949157715,
#   'foreign': 'KX261851.1',
#   'indo': 'KF258813.1',
#   'location': 'Colombia',
#   'score': -35.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.15459704399108887,
#   'foreign': 'KT381874.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -35.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4578089714050293,
#   'foreign': 'KU232297.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -35.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.15009403228759766,
#   'foreign': 'KU926326.1',
#   'indo': 'KF258813.1',
#   'location': 'Israel',
#   'score': -36.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.1506211757659912,
#   'foreign': 'KU926325.1',
#   'indo': 'KF258813.1',
#   'location': 'Israel',
#   'score': -36.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.15009379386901855,
#   'foreign': 'KU926324.1',
#   'indo': 'KF258813.1',
#   'location': 'Israel',
#   'score': -36.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.15162014961242676,
#   'foreign': 'KU926323.1',
#   'indo': 'KF258813.1',
#   'location': 'Israel',
#   'score': -36.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.15609288215637207,
#   'foreign': 'KU954085.1',
#   'indo': 'KF258813.1',
#   'location': 'Colombia',
#   'score': -38.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.14760494232177734,
#   'foreign': 'KM212961.1',
#   'indo': 'KF258813.1',
#   'location': 'New Caledonia',
#   'score': -48.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.12459397315979004,
#   'foreign': 'KX358623.1',
#   'indo': 'KF258813.1',
#   'location': 'Venezuela',
#   'score': -64.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.49583888053894043,
#   'foreign': 'KU556802.1',
#   'indo': 'KF258813.1',
#   'location': 'Mexico',
#   'score': -64.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.479841947555542,
#   'foreign': 'KU724096.1',
#   'indo': 'KF258813.1',
#   'location': 'Panama',
#   'score': -67.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.4948701858520508,
#   'foreign': 'KU985087.1',
#   'indo': 'KF258813.1',
#   'location': 'Mexico',
#   'score': -68.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.13211512565612793,
#   'foreign': 'KJ461621.1',
#   'indo': 'KF258813.1',
#   'location': 'Norway',
#   'score': -71.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.46933698654174805,
#   'foreign': 'KT200609.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -72.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5218589305877686,
#   'foreign': 'KM851038.1',
#   'indo': 'KF258813.1',
#   'location': 'Philippines',
#   'score': -98.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5264101028442383,
#   'foreign': 'KM851039.1',
#   'indo': 'KF258813.1',
#   'location': 'Thailand',
#   'score': -100.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5223710536956787,
#   'foreign': 'KJ873161.1',
#   'indo': 'KF258813.1',
#   'location': 'New Caledonia',
#   'score': -103.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5238738059997559,
#   'foreign': 'KF270887.1',
#   'indo': 'KF258813.1',
#   'location': 'Gabon',
#   'score': -105.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5569422245025635,
#   'foreign': 'KF270886.1',
#   'indo': 'KF258813.1',
#   'location': 'Gabon',
#   'score': -143.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5598850250244141,
#   'foreign': 'KX173844.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -145.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5619001388549805,
#   'foreign': 'KX173843.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -147.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.5934228897094727,
#   'foreign': 'KJ873160.1',
#   'indo': 'KF258813.1',
#   'location': 'New Caledonia',
#   'score': -165.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6149559020996094,
#   'foreign': 'KX173841.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -200.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6134190559387207,
#   'foreign': 'KX173840.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -200.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6449770927429199,
#   'foreign': 'KM078979.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6439599990844727,
#   'foreign': 'KM078978.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6494460105895996,
#   'foreign': 'KM078977.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6679739952087402,
#   'foreign': 'KM078976.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.638455867767334,
#   'foreign': 'KM078975.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6414740085601807,
#   'foreign': 'KM078974.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6454410552978516,
#   'foreign': 'KM078973.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.646461009979248,
#   'foreign': 'KM078972.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6464779376983643,
#   'foreign': 'KM078971.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6459600925445557,
#   'foreign': 'KM078970.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6469478607177734,
#   'foreign': 'KM078969.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.642003059387207,
#   'foreign': 'KM078968.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6419589519500732,
#   'foreign': 'KM078967.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6464769840240479,
#   'foreign': 'KM078966.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6444590091705322,
#   'foreign': 'KM078965.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6464419364929199,
#   'foreign': 'KM078964.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6474621295928955,
#   'foreign': 'KM078963.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6424760818481445,
#   'foreign': 'KM078962.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.640955924987793,
#   'foreign': 'KM078960.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6444590091705322,
#   'foreign': 'KM078959.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6470229625701904,
#   'foreign': 'KM078958.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6444411277770996,
#   'foreign': 'KM078957.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6444768905639648,
#   'foreign': 'KM078956.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6474611759185791,
#   'foreign': 'KM078955.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.636077880859375,
#   'foreign': 'KM078954.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.642941951751709,
#   'foreign': 'KM078953.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6434760093688965,
#   'foreign': 'KM078952.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6439390182495117,
#   'foreign': 'KM078951.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6424591541290283,
#   'foreign': 'KM078950.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6419739723205566,
#   'foreign': 'KM078949.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6474878787994385,
#   'foreign': 'KM078948.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6721010208129883,
#   'foreign': 'KM078947.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6910550594329834,
#   'foreign': 'KM078946.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6849870681762695,
#   'foreign': 'KM078945.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6826009750366211,
#   'foreign': 'KM078944.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6869900226593018,
#   'foreign': 'KM078943.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6936168670654297,
#   'foreign': 'KM078942.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6839959621429443,
#   'foreign': 'KM078941.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6631109714508057,
#   'foreign': 'KM078940.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.645942211151123,
#   'foreign': 'KM078939.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6474788188934326,
#   'foreign': 'KM078938.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6449601650238037,
#   'foreign': 'KM078937.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6424388885498047,
#   'foreign': 'KM078936.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6434581279754639,
#   'foreign': 'KM078935.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6489808559417725,
#   'foreign': 'KM078934.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6419389247894287,
#   'foreign': 'KM078932.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.640455961227417,
#   'foreign': 'KM078931.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6449670791625977,
#   'foreign': 'KM078930.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6460080146789551,
#   'foreign': 'KM078929.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -238.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6449708938598633,
#   'foreign': 'KM078961.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -239.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6454601287841797,
#   'foreign': 'KM078933.1',
#   'indo': 'KF258813.1',
#   'location': 'Chile',
#   'score': -239.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6804888248443604,
#   'foreign': 'KX059014.1',
#   'indo': 'KF258813.1',
#   'location': 'Haiti',
#   'score': -273.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.6739811897277832,
#   'foreign': 'KX059013.1',
#   'indo': 'KF258813.1',
#   'location': 'Haiti',
#   'score': -273.0},
#  {'alignment': 'Global',
#   'elapsed_time': 0.850100040435791,
#   'foreign': 'KU686218.1',
#   'indo': 'KF258813.1',
#   'location': 'Mexico',
#   'score': -491.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.0067222118377686,
#   'foreign': 'KJ634273.1',
#   'indo': 'KF258813.1',
#   'location': 'Cook Islands',
#   'score': -712.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.2033557891845703,
#   'foreign': 'KU740199.1',
#   'indo': 'KF258813.1',
#   'location': 'China',
#   'score': -1009.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.4761548042297363,
#   'foreign': 'KU312315.1',
#   'indo': 'KF258813.1',
#   'location': 'Suriname',
#   'score': -1118.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.7522480487823486,
#   'foreign': 'KU646828.1',
#   'indo': 'KF258813.1',
#   'location': 'Colombia',
#   'score': -1797.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.7387919425964355,
#   'foreign': 'KU646827.1',
#   'indo': 'KF258813.1',
#   'location': 'Colombia',
#   'score': -1797.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8663301467895508,
#   'foreign': 'KX212103.1',
#   'indo': 'KF258813.1',
#   'location': 'Brazil',
#   'score': -2005.0},
#  {'alignment': 'Global',
#   'elapsed_time': 2.400315046310425,
#   'foreign': 'KU312314.1',
#   'indo': 'KF258813.1',
#   'location': 'Suriname',
#   'score': -2021.0},
#  {'alignment': 'Global',
#   'elapsed_time': 2.3394761085510254,
#   'foreign': 'KU312313.1',
#   'indo': 'KF258813.1',
#   'location': 'Suriname',
#   'score': -2022.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8853600025177002,
#   'foreign': 'KU758874.1',
#   'indo': 'KF258813.1',
#   'location': 'French Guiana',
#   'score': -2036.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.8883471488952637,
#   'foreign': 'KU758868.1',
#   'indo': 'KF258813.1',
#   'location': 'French Guiana',
#   'score': -2036.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.9143650531768799,
#   'foreign': 'KU758869.1',
#   'indo': 'KF258813.1',
#   'location': 'French Guiana',
#   'score': -2050.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.9088780879974365,
#   'foreign': 'KU758876.1',
#   'indo': 'KF258813.1',
#   'location': 'Suriname',
#   'score': -2060.0},
#  {'alignment': 'Global',
#   'elapsed_time': 2.0209548473358154,
#   'foreign': 'KU758870.1',
#   'indo': 'KF258813.1',
#   'location': 'French Guiana',
#   'score': -2061.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.942383050918579,
#   'foreign': 'KU758872.1',
#   'indo': 'KF258813.1',
#   'location': 'French Guiana',
#   'score': -2062.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.9073419570922852,
#   'foreign': 'KU758873.1',
#   'indo': 'KF258813.1',
#   'location': 'French Guiana',
#   'score': -2064.0},
#  {'alignment': 'Global',
#   'elapsed_time': 2.0035040378570557,
#   'foreign': 'KU758871.1',
#   'indo': 'KF258813.1',
#   'location': 'French Guiana',
#   'score': -2064.0},
#  {'alignment': 'Global',
#   'elapsed_time': 1.9223508834838867,
#   'foreign': 'KU758875.1',
#   'indo': 'KF258813.1',
#   'location': 'French Guiana',
#   'score': -2078.0}]
